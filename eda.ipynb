# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_csv('data.csv')
df.head()
# Out:
#    Unnamed: 0                                          adj_pairs  \
# 0           0  [{'average_voltage': 2.3251851700000024, 'max_...
# 1           0  [{'average_voltage': 3.291747695000003, 'max_v...
# 2           0  [{'average_voltage': 5.06257936249998, 'max_vo...
# 3           0  [{'average_voltage': 3.2011691699999907, 'max_...
# 4           0  [{'average_voltage': 2.4383090549999955, 'max_...
#
#    average_voltage         battid  capacity_grav  capacity_vol  energy_grav  \
# 0         2.325185   mp-504791_Li      50.228609    269.262771   116.790816
# 1         3.291748   mp-763480_Li      39.674483    154.215698   130.598387
# 2         3.609671  mp-1176966_Li     181.943205    651.708695   656.755144
# 3         3.201169    mvc-5592_Li      73.484217    329.726946   235.235410
# 4         2.438309   mp-763566_Li      73.484217    306.081406   179.177232
#
#     energy_vol                                          framework  max_frac  \
# 0   626.085802  {'reduced_cell_composition': {'P': 1.0, 'W': 2...  0.083333
# 1   507.639167  {'reduced_cell_composition': {'P': 3.0, 'W': 2...  0.052632
# 2  2352.454095  {'reduced_cell_composition': {'P': 8.0, 'W': 3...  0.183673
# 3  1055.511733  {'reduced_cell_composition': {'P': 2.0, 'W': 1...  0.090909
# 4   746.321063  {'reduced_cell_composition': {'P': 2.0, 'W': 1...  0.090909
#
#    ...  min_frac  min_instability  min_voltage  nsteps  numsites  \
# 0  ...       0.0         0.000000     2.325185       1        11
# 1  ...       0.0         0.000097     3.291748       1        18
# 2  ...       0.0         0.025051     2.660169       3        40
# 3  ...       0.0         0.049028     3.201169       1        10
# 4  ...       0.0         0.000000     2.438309       1        10
#
#           reduced_cell_composition reduced_cell_formula  \
# 0   {'P': 1.0, 'W': 2.0, 'O': 8.0}              P(WO4)2
# 1  {'P': 3.0, 'W': 2.0, 'O': 13.0}              P3W2O13
# 2  {'P': 8.0, 'W': 3.0, 'O': 29.0}              P8W3O29
# 3   {'P': 2.0, 'W': 1.0, 'O': 7.0}                P2WO7
# 4   {'P': 2.0, 'W': 1.0, 'O': 7.0}                P2WO7
#
#                                           spacegroup           type  \
# 0  {'number': 19, 'hall_number': 115, 'internatio...  intercalation
# 1  {'number': 14, 'hall_number': 81, 'internation...  intercalation
# 2  {'number': 165, 'hall_number': 457, 'internati...  intercalation
# 3  {'number': 2, 'hall_number': 2, 'international...  intercalation
# 4  {'number': 4, 'hall_number': 6, 'international...  intercalation
#
#   working_ion
# 0          Li
# 1          Li
# 2          Li
# 3          Li
# 4          Li
#
# [5 rows x 21 columns]

# %%
df.dtypes
# Out:
# Unnamed: 0                    int64
# adj_pairs                    object
# average_voltage             float64
# battid                       object
# capacity_grav               float64
# capacity_vol                float64
# energy_grav                 float64
# energy_vol                  float64
# framework                    object
# max_frac                    float64
# max_voltage                 float64
# min_frac                    float64
# min_instability             float64
# min_voltage                 float64
# nsteps                        int64
# numsites                      int64
# reduced_cell_composition     object
# reduced_cell_formula         object
# spacegroup                   object
# type                         object
# working_ion                  object
# dtype: object

# %%
df =df.select_dtypes(exclude=['object'])
df.head()
# Out:
#    Unnamed: 0  average_voltage  capacity_grav  capacity_vol  energy_grav  \
# 0           0         2.325185      50.228609    269.262771   116.790816
# 1           0         3.291748      39.674483    154.215698   130.598387
# 2           0         3.609671     181.943205    651.708695   656.755144
# 3           0         3.201169      73.484217    329.726946   235.235410
# 4           0         2.438309      73.484217    306.081406   179.177232
#
#     energy_vol  max_frac  max_voltage  min_frac  min_instability  min_voltage  \
# 0   626.085802  0.083333     2.325185       0.0         0.000000     2.325185
# 1   507.639167  0.052632     3.291748       0.0         0.000097     3.291748
# 2  2352.454095  0.183673     5.062579       0.0         0.025051     2.660169
# 3  1055.511733  0.090909     3.201169       0.0         0.049028     3.201169
# 4   746.321063  0.090909     2.438309       0.0         0.000000     2.438309
#
#    nsteps  numsites
# 0       1        11
# 1       1        18
# 2       3        40
# 3       1        10
# 4       1        10

# %%
df=df.drop(['Unnamed: 0'],axis=1)
df.head()
# Out:
#    average_voltage  capacity_grav  capacity_vol  energy_grav   energy_vol  \
# 0         2.325185      50.228609    269.262771   116.790816   626.085802
# 1         3.291748      39.674483    154.215698   130.598387   507.639167
# 2         3.609671     181.943205    651.708695   656.755144  2352.454095
# 3         3.201169      73.484217    329.726946   235.235410  1055.511733
# 4         2.438309      73.484217    306.081406   179.177232   746.321063
#
#    max_frac  max_voltage  min_frac  min_instability  min_voltage  nsteps  \
# 0  0.083333     2.325185       0.0         0.000000     2.325185       1
# 1  0.052632     3.291748       0.0         0.000097     3.291748       1
# 2  0.183673     5.062579       0.0         0.025051     2.660169       3
# 3  0.090909     3.201169       0.0         0.049028     3.201169       1
# 4  0.090909     2.438309       0.0         0.000000     2.438309       1
#
#    numsites
# 0        11
# 1        18
# 2        40
# 3        10
# 4        10

# %%
df.dtypes
# Out:
# average_voltage    float64
# capacity_grav      float64
# capacity_vol       float64
# energy_grav        float64
# energy_vol         float64
# max_frac           float64
# max_voltage        float64
# min_frac           float64
# min_instability    float64
# min_voltage        float64
# nsteps               int64
# numsites             int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# average_voltage    0
# capacity_grav      0
# capacity_vol       0
# energy_grav        0
# energy_vol         0
# max_frac           0
# max_voltage        0
# min_frac           0
# min_instability    0
# min_voltage        0
# nsteps             0
# numsites           0
# dtype: int64

# %%
dfile=df.to_csv('dfile.csv')

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
corr=df.corr()

f, ax = plt.subplots(figsize=(10, 8))

sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(240,10,as_cmap=True),
            square=True, ax=ax)
# Out:
# /tmp/ipykernel_37131/1216220937.py:5: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(240,10,as_cmap=True),
# <AxesSubplot:>

# %%
df.columns[4]
# Out:
# 'energy_vol'

# %%
sns.set_style("white")

for name in df.columns:
    print(name)

    sns.kdeplot(data= df,x=name,color='purple',shade=True)
    
    plt.savefig('EDA images/'+name+'.png')
    plt.show()
# Out:
# average_voltage
# capacity_grav
# capacity_vol
# energy_grav
# energy_vol
# max_frac
# max_voltage
# min_frac
# min_instability
# min_voltage
# nsteps
# numsites

# %%
sns.kdeplot(data= df,x='capacity_grav',fill=True,palette='Tab20')
# Out:
# <AxesSubplot:xlabel='capacity_grav', ylabel='Density'>
